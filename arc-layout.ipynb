# %% [markdown]
# The code below will load d3.js with require.js
#
# If you don't know what require js does, all you need to know is it manages dependencies, and we need to hook into it in order for our page to correctly access the d3 module

# %%
# %%javascript
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min"
#   }
# });
#
# require(["d3"], function(d3) {
# //   d3.select("body").prepend("h1").text("Successfully loaded D3 version " + d3.version);
#     alert("Loaded d3");
#     console.log("%c%s",
#             "color: red; background: yellow; font-size: 24px;",
#             "Successfully loaded d3:");
#     console.log(d3);
# });

# %%
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets
import d3_lib
import json
import random
# HTML('<script src="lib/d3/d3.min.js"></script>')

# num_nodes = 30
# num_edges = 0.05

# slider_nodes = widgets.IntSlider()
# slider_edges = widgets.IntSlider()
submit_button = widgets.Button(description="Create Graph")

# display(slider_nodes)
# display(slider_edges)
display(submit_button)


def slider_nodes_handler(change):
    num_nodes = change['new']
    
def slider_edges_handler(change):
    num_edges = change['new']

    
def on_button_click(change):
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    display_graph()
#     print("=========================================================")
    
# slider_nodes.observe(slider_nodes_handler, names='value')
# slider_edges.observe(slider_edges_handler, names='value')

submit_button.on_click(on_button_click)



def display_graph(): 
    clear_output()
    display(HTML(d3_lib.set_styles(['arc'])))
#     display(HTML(d3_lib.draw_graph_from_graphml('arc', "./data_sets/G.graphml")))
    display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "degree_centrality", 30)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "load_centrality", 10000)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "closeness_centrality", 10)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "communicability", 100)))
# Out:
# <style>@-webkit-keyframes dash {
#   to {
#     stroke-dashoffset: 1000;
#   }
# }
#
# body {
#     font-family: 'Source Sans Pro', sans-serif;
#     font-weight: 300;
# }
#
# b {
#     font-weight: 900;
# }
#
# .outline {
#     fill: none;
#     stroke: #888888;
#     stroke-width: 1px;
# }
#
# #tooltip {
#     font-size: 10pt;
#     font-weight: 900;
#
#     fill: #000000;
#     stroke: #ffffff;
#     stroke-width: 0.25px;
# }
#
# .node {
#     stroke: #ffffff;
#     stroke-weight: 1px;
# }
#
# .link {
#     fill: none;
#     stroke: #888888;
#     stroke-weight: 1px;
#     stroke-opacity: 0.5;
#     /*-webkit-animation: dash;*/
#
#
# }
#
# /*.animated-link {
#   animation: dash 60s linear infinite;
#   animation-direction: reverse;
#     stroke-dasharray: 8;
# }*/
#
# .highlight {
#     stroke: red;
#     stroke-weight: 4px;
#     stroke-opacity: 1.0;
# }
# </style>
# Un-normalized centrality numbers
# {   '1': 0.24489795918367346,
#     '10': 0.2857142857142857,
#     '11': 0.36734693877551017,
#     '12': 0.4897959183673469,
#     '13': 0.4081632653061224,
#     '14': 0.2040816326530612,
#     '15': 0.3877551020408163,
#     '16': 0.42857142857142855,
#     '17': 0.4693877551020408,
#     '18': 0.32653061224489793,
#     '19': 0.5102040816326531,
#     '2': 0.16326530612244897,
#     '20': 0.3877551020408163,
#     '21': 0.3469387755102041,
#     '22': 0.44897959183673464,
#     '23': 0.42857142857142855,
#     '24': 0.24489795918367346,
#     '25': 0.4081632653061224,
#     '26': 0.2040816326530612,
#     '27': 0.2857142857142857,
#     '28': 0.3469387755102041,
#     '29': 0.3061224489795918,
#     '3': 0.44897959183673464,
#     '30': 0.4081632653061224,
#     '31': 0.2857142857142857,
#     '32': 0.5714285714285714,
#     '33': 0.2857142857142857,
#     '34': 0.3877551020408163,
#     '35': 0.08163265306122448,
#     '36': 0.4081632653061224,
#     '37': 0.2857142857142857,
#     '38': 0.3469387755102041,
#     '39': 0.32653061224489793,
#     '4': 0.42857142857142855,
#     '40': 0.42857142857142855,
#     '41': 0.32653061224489793,
#     '42': 0.4081632653061224,
#     '43': 0.5510204081632653,
#     '44': 0.3061224489795918,
#     '45': 0.4897959183673469,
#     '46': 0.2040816326530612,
#     '47': 0.24489795918367346,
#     '48': 0.5306122448979591,
#     '49': 0.24489795918367346,
#     '5': 0.3877551020408163,
#     '50': 0.3469387755102041,
#     '6': 0.36734693877551017,
#     '7': 0.5306122448979591,
#     '8': 0.36734693877551017,
#     '9': 0.26530612244897955}
# {   '1': 0.409090909090909,
#     '10': 0.4772727272727272,
#     '11': 0.6136363636363634,
#     '12': 0.818181818181818,
#     '13': 0.6818181818181817,
#     '14': 0.34090909090909083,
#     '15': 0.6477272727272726,
#     '16': 0.7159090909090907,
#     '17': 0.784090909090909,
#     '18': 0.5454545454545453,
#     '19': 0.8522727272727272,
#     '2': 0.27272727272727265,
#     '20': 0.6477272727272726,
#     '21': 0.5795454545454545,
#     '22': 0.7499999999999998,
#     '23': 0.7159090909090907,
#     '24': 0.409090909090909,
#     '25': 0.6818181818181817,
#     '26': 0.34090909090909083,
#     '27': 0.4772727272727272,
#     '28': 0.5795454545454545,
#     '29': 0.5113636363636362,
#     '3': 0.7499999999999998,
#     '30': 0.6818181818181817,
#     '31': 0.4772727272727272,
#     '32': 0.9545454545454544,
#     '33': 0.4772727272727272,
#     '34': 0.6477272727272726,
#     '35': 0.13636363636363633,
#     '36': 0.6818181818181817,
#     '37': 0.4772727272727272,
#     '38': 0.5795454545454545,
#     '39': 0.5454545454545453,
#     '4': 0.7159090909090907,
#     '40': 0.7159090909090907,
#     '41': 0.5454545454545453,
#     '42': 0.6818181818181817,
#     '43': 0.9204545454545452,
#     '44': 0.5113636363636362,
#     '45': 0.818181818181818,
#     '46': 0.34090909090909083,
#     '47': 0.409090909090909,
#     '48': 0.8863636363636361,
#     '49': 0.409090909090909,
#     '5': 0.6477272727272726,
#     '50': 0.5795454545454545,
#     '6': 0.6136363636363634,
#     '7': 0.8863636363636361,
#     '8': 0.6136363636363634,
#     '9': 0.44318181818181807}
#                 <div id='maindiv5784258149'></div>
#
#                 <script>
#                     /* GLOBALS */
#
# var width  = 1000;           // width of svg image
# var height = 1000;           // height of svg image
# var margin = 20;            // amount of margin around plot area
# var pad = margin / 2;       // actual padding amount
# var radius = 10;             // fixed node radius
# var yfixed = 400 - pad - radius;  // y position for all nodes
# var xfixed = pad + radius;
#
# var json_data = {"graph": {"node_default": {}, "edge_default": {}}, "nodes": [{"y": 471, "id": "47", "x": 20, "algorithm_filter": 0.409090909090909}, {"y": 331, "id": "34", "x": 87, "algorithm_filter": 0.6477272727272726}, {"y": 331, "id": "42", "x": 412, "algorithm_filter": 0.6818181818181817}, {"y": 7, "id": "2", "x": 232, "algorithm_filter": 0.27272727272727265}, {"y": 429, "id": "30", "x": 215, "algorithm_filter": 0.6818181818181817}, {"y": 490, "id": "14", "x": 387, "algorithm_filter": 0.34090909090909083}, {"y": 240, "id": "24", "x": 13, "algorithm_filter": 0.409090909090909}, {"y": 400, "id": "25", "x": 124, "algorithm_filter": 0.6818181818181817}, {"y": 368, "id": "22", "x": 148, "algorithm_filter": 0.7499999999999998}, {"y": 219, "id": "12", "x": 386, "algorithm_filter": 0.818181818181818}, {"y": 384, "id": "17", "x": 301, "algorithm_filter": 0.784090909090909}, {"y": 311, "id": "20", "x": 86, "algorithm_filter": 0.6477272727272726}, {"y": 418, "id": "11", "x": 175, "algorithm_filter": 0.6136363636363634}, {"y": 170, "id": "37", "x": 121, "algorithm_filter": 0.4772727272727272}, {"y": 253, "id": "19", "x": 200, "algorithm_filter": 0.8522727272727272}, {"y": 184, "id": "3", "x": 333, "algorithm_filter": 0.7499999999999998}, {"y": 10, "id": "35", "x": 72, "algorithm_filter": 0.13636363636363633}, {"y": 204, "id": "28", "x": 460, "algorithm_filter": 0.5795454545454545}, {"y": 166, "id": "33", "x": 496, "algorithm_filter": 0.4772727272727272}, {"y": 276, "id": "1", "x": 15, "algorithm_filter": 0.409090909090909}, {"y": 163, "id": "21", "x": 463, "algorithm_filter": 0.5795454545454545}, {"y": 220, "id": "50", "x": 479, "algorithm_filter": 0.5795454545454545}, {"y": 376, "id": "23", "x": 156, "algorithm_filter": 0.7159090909090907}, {"y": 490, "id": "10", "x": 127, "algorithm_filter": 0.4772727272727272}, {"y": 140, "id": "38", "x": 444, "algorithm_filter": 0.5795454545454545}, {"y": 332, "id": "8", "x": 46, "algorithm_filter": 0.6136363636363634}, {"y": 421, "id": "9", "x": 418, "algorithm_filter": 0.44318181818181807}, {"y": 57, "id": "29", "x": 295, "algorithm_filter": 0.5113636363636362}, {"y": 413, "id": "6", "x": 359, "algorithm_filter": 0.6136363636363634}, {"y": 262, "id": "31", "x": 61, "algorithm_filter": 0.4772727272727272}, {"y": 412, "id": "46", "x": 477, "algorithm_filter": 0.34090909090909083}, {"y": 149, "id": "4", "x": 328, "algorithm_filter": 0.7159090909090907}, {"y": 345, "id": "7", "x": 245, "algorithm_filter": 0.8863636363636361}, {"y": 420, "id": "40", "x": 289, "algorithm_filter": 0.7159090909090907}, {"y": 113, "id": "27", "x": 471, "algorithm_filter": 0.4772727272727272}, {"y": 291, "id": "16", "x": 444, "algorithm_filter": 0.7159090909090907}, {"y": 34, "id": "26", "x": 219, "algorithm_filter": 0.34090909090909083}, {"y": 224, "id": "48", "x": 315, "algorithm_filter": 0.8863636363636361}, {"y": 249, "id": "43", "x": 345, "algorithm_filter": 0.9204545454545452}, {"y": 155, "id": "15", "x": 174, "algorithm_filter": 0.6477272727272726}, {"y": 472, "id": "49", "x": 56, "algorithm_filter": 0.409090909090909}, {"y": 403, "id": "39", "x": 394, "algorithm_filter": 0.5454545454545453}, {"y": 105, "id": "5", "x": 339, "algorithm_filter": 0.6477272727272726}, {"y": 129, "id": "41", "x": 423, "algorithm_filter": 0.5454545454545453}, {"y": 377, "id": "18", "x": 425, "algorithm_filter": 0.5454545454545453}, {"y": 401, "id": "13", "x": 184, "algorithm_filter": 0.6818181818181817}, {"y": 493, "id": "44", "x": 252, "algorithm_filter": 0.5113636363636362}, {"y": 184, "id": "36", "x": 276, "algorithm_filter": 0.6818181818181817}, {"y": 219, "id": "45", "x": 207, "algorithm_filter": 0.818181818181818}, {"y": 265, "id": "32", "x": 309, "algorithm_filter": 0.9545454545454544}], "directed": false, "multigraph": false, "links": [{"target": 23, "source": 0}, {"target": 4, "source": 0}, {"target": 25, "source": 0}, {"target": 40, "source": 0}, {"target": 1, "source": 0}, {"target": 22, "source": 0}, {"target": 45, "source" ...
