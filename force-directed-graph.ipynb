# %% [markdown]
# The code below will load d3.js with require.js
#
# If you don't know what require js does, all you need to know is it manages dependencies, and we need to hook into it in order for our page to correctly access the d3 module

# %%
# %%javascript
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min"
#   }
# });
#
# require(["d3"], function(d3) {
# //   d3.select("body").prepend("h1").text("Successfully loaded D3 version " + d3.version);
#     alert("Loaded d3");
#     console.log("%c%s",
#             "color: red; background: yellow; font-size: 24px;",
#             "Successfully loaded d3:");
#     console.log(d3);
# });

# %%
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets
import d3_lib
import json
import random
# HTML('<script src="lib/d3/d3.min.js"></script>')

# num_nodes = 30
# num_edges = 0.05

# slider_nodes = widgets.IntSlider()
# slider_edges = widgets.IntSlider()
submit_button = widgets.Button(description="Create Graph")

# display(slider_nodes)
# display(slider_edges)
display(submit_button)


def slider_nodes_handler(change):
    num_nodes = change['new']
    
def slider_edges_handler(change):
    num_edges = change['new']

    
def on_button_click(change):
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    display_graph()
#     print("=========================================================")
    
# slider_nodes.observe(slider_nodes_handler, names='value')
# slider_edges.observe(slider_edges_handler, names='value')

submit_button.on_click(on_button_click)



def display_graph(): 
    clear_output()
#     display(HTML(d3_lib.set_styles(['force_directed_graph'])))
#     display(HTML(d3_lib.draw_graph_from_graphml('force_directed_graph', "./data_sets/G.graphml")))
    display(HTML(d3_lib.set_styles(['custom_force_directed'])))
    display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('custom_force_directed', "./data_sets/G.graphml", "communicability", .000001)))

#     display(HTML(d3_lib.draw_graph_from_graphml('custom_force_directed', "./data_sets/G.graphml")))
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
# @-webkit-keyframes dash {
#   to {
#     stroke-dashoffset: 1000;
#   }
# }
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
#   -webkit-animation: dash 60s linear infinite;
#   animation-direction: reverse;
#   stroke-dasharray: 10, 20;
# }
#
# .fixed {
#   border: 2px solid black;
# }
# </style>
#                 <div id='maindiv5064638070'></div>
#
#                 <script>
#                     var width = 1000;
# var height = 1000;
# var default_color = "grey"
# var color = d3.scale.category20();
#
# var graph = {"links": [{"weight": 4.314587256305684, "target": 14, "source": 0}, {"weight": 5.43744235570315, "target": 15, "source": 0}, {"weight": 3.479225090771276, "target": 30, "source": 0}, {"weight": 5.017445873261421, "target": 39, "source": 0}, {"weight": 4.797707782321774, "target": 31, "source": 0}, {"weight": 6.586617216388087, "target": 33, "source": 0}, {"weight": 6.436645198433464, "target": 2, "source": 0}, {"weight": 4.966864550674665, "target": 21, "source": 0}, {"weight": 4.293684416352347, "target": 22, "source": 0}, {"weight": 4.181736479708161, "target": 23, "source": 0}, {"weight": 4.435289269106238, "target": 45, "source": 0}, {"weight": 6.012155281416308, "target": 46, "source": 0}, {"weight": 4.0573257654902015, "target": 48, "source": 0}, {"weight": 4.293684416352346, "target": 27, "source": 0}, {"weight": 4.581256808895167, "target": 13, "source": 1}, {"weight": 5.2547073632193, "target": 29, "source": 1}, {"weight": 4.581256808895166, "target": 16, "source": 1}, {"weight": 3.491139564042866, "target": 43, "source": 1}, {"weight": 5.917080034954517, "target": 36, "source": 1}, {"weight": 5.011229279750169, "target": 18, "source": 1}, {"weight": 5.428073410839623, "target": 32, "source": 1}, {"weight": 6.740136340009742, "target": 42, "source": 1}, {"weight": 7.643417993048038, "target": 10, "source": 1}, {"weight": 5.247371544292786, "target": 3, "source": 1}, {"weight": 4.345497837150545, "target": 4, "source": 1}, {"weight": 8.48233339894367, "target": 34, "source": 1}, {"weight": 3.5263913193280514, "target": 24, "source": 1}, {"weight": 2.8064234827846803, "target": 6, "source": 1}, {"weight": 3.853227801393878, "target": 47, "source": 1}, {"weight": 2.8584383219003975, "target": 8, "source": 1}, {"weight": 4.644700547188286, "target": 35, "source": 1}, {"weight": 7.215898468467415, "target": 9, "source": 1}, {"weight": 5.575811353066923, "target": 37, "source": 1}, {"weight": 6.8841530576552845, "target": 25, "source": 1}, {"weight": 9.127670354177496, "target": 39, "source": 2}, {"weight": 7.842144287916353, "target": 14, "source": 2}, {"weight": 11.993877543483384, "target": 33, "source": 2}, {"weight": 12.596201793761958, "target": 34, "source": 2}, {"weight": 10.591409361752747, "target": 9, "source": 2}, {"weight": 7.769724115494145, "target": 29, "source": 2}, {"weight": 9.929268451802898, "target": 42, "source": 2}, {"weight": 8.692256748295627, "target": 36, "source": 2}, {"weight": 10.944129284146731, "target": 46, "source": 2}, {"weight": 8.064816454414556, "target": 45, "source": 2}, {"weight": 7.053831073693498, "target": 38, "source": 2}, {"weight": 8.737407945842529, "target": 31, "source": 2}, {"weight": 9.894389680799764, "target": 15, "source": 2}, {"weight": 6.320128688294016, "target": 30, "source": 2}, {"weight": 7.164218860883882, "target": 41, "source": 2}, {"weight": 8.798503890409537, "target": 17, "source": 2}, {"weight": 7.094492254743588, "target": 19, "source": 2}, {"weight": 11.234371540418614, "target": 10, "source": 2}, {"weight": 9.034768783986307, "target": 21, "source": 2}, {"weight": 7.803160365586478, "target": 22, "source": 2}, {"weight": 7.600874870127178, "target": 23, "source": 2}, {"weight": 10.142653104643111, "target": 25, "source": 2}, {"weight": 6.367160981907576, "target": 7, "source": 2}, {"weight": 7.373044508377254, "target": 48, "source": 2}, {"weight": 7.803160365586476, "target": 27, "source": 2}, {"weight": 4.4507058073926125, "target": 13, "source": 3}, {"weight": 2.4564865647049468, "target": 5, "source": 3}, {"weight": 5.1086015304442665, "target": 29, "source": 3}, {"weight": 4.4507058073926125, "target": 16, "source": 3}, {"weight": 6.55187232245732, "target": 42, "source": 3}, {"weight": 4.868642006021667, "target": 18, "source": 3}, {"weight": 5.273947466372697, "target": 32, "source": 3}, {"weight": 7.4292601463388, "target": 10, "source": 3}, {"weight": 8.24716300606023, "target": 34, "source": 3}, {"weight": 4.22153284227759, "targe ...
