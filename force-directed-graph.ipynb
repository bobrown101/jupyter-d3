# %% [markdown]
# The code below will load d3.js with require.js
#
# If you don't know what require js does, all you need to know is it manages dependencies, and we need to hook into it in order for our page to correctly access the d3 module

# %%
# %%javascript
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min"
#   }
# });
#
# require(["d3"], function(d3) {
# //   d3.select("body").prepend("h1").text("Successfully loaded D3 version " + d3.version);
#     alert("Loaded d3");
#     console.log("%c%s",
#             "color: red; background: yellow; font-size: 24px;",
#             "Successfully loaded d3:");
#     console.log(d3);
# });

# %%
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets
import d3_lib
import random
HTML('<script src="lib/d3/d3.min.js"></script>')

num_nodes = 30
num_edges = 0.05

slider_nodes = widgets.IntSlider()
slider_edges = widgets.IntSlider()
submit_button = widgets.Button(description="Create Graph")

display(slider_nodes)
display(slider_edges)
display(submit_button)


def slider_nodes_handler(change):
    num_nodes = change['new']
    
def slider_edges_handler(change):
    num_edges = change['new']

    
def on_button_click(change):
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    display_graph(num_nodes, num_edges)
    print("=========================================================")
    
slider_nodes.observe(slider_nodes_handler, names='value')
slider_edges.observe(slider_edges_handler, names='value')

submit_button.on_click(on_button_click)


def display_graph(num_nodes, num_edges): 
    graph = {"nodes": [], "links": []}
    for i in range(num_nodes):
        graph["nodes"].append( {"name": "i" + str(i), "group": int(random.uniform(1,100))} )
    for i in range(num_nodes):
        for j in range(num_nodes):
            if random.uniform(0,1) < num_edges:
                graph["links"].append( {"source": i, "target": j, "value": random.uniform(1,30)} )
    clear_output()
    display(HTML(d3_lib.set_styles(['force_directed_graph'])))
    display(HTML(d3_lib.draw_graph('force_directed_graph',{'data': graph})))
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }
#
# .fixed {
#   border: 2px solid black;
# }
# </style>
#
#                 <div id='maindiv8859100140'></div>
#
#                 <script>
#
# // Based on http://bl.ocks.org/mbostock/4062045
#
# var width = 960,
#     height = 500;
#
# var color = d3.scale.category20();
#
# var force = d3.layout.force()
#     .charge(-300)
#     .linkDistance(50)
#     .size([width, height]);
#
# d3.select("#maindiv8859100140").selectAll("svg").remove();
# var svg = d3.select("#maindiv8859100140").append("svg")
#     .attr("width", width)
#     .attr("height", height);
#
# //d3.json("miserables.json", function(error, graph) {
# //  if (error) throw error;
# var graph = {'links': [{'source': 4, 'target': 11, 'value': 13.712342485204642}, {'source': 4, 'target': 24, 'value': 29.34120600119511}, {'source': 4, 'target': 27, 'value': 9.539856747116595}, {'source': 5, 'target': 15, 'value': 20.022248780536557}, {'source': 5, 'target': 19, 'value': 1.7336571921377373}, {'source': 6, 'target': 12, 'value': 24.929381901213052}, {'source': 7, 'target': 25, 'value': 24.175378215180263}, {'source': 8, 'target': 17, 'value': 11.011615586907626}, {'source': 9, 'target': 29, 'value': 6.036066627021024}, {'source': 10, 'target': 2, 'value': 5.378113206860059}, {'source': 10, 'target': 8, 'value': 28.841333765102576}, {'source': 11, 'target': 10, 'value': 22.08349800787709}, {'source': 13, 'target': 14, 'value': 13.985649601826841}, {'source': 14, 'target': 23, 'value': 23.41665688057095}, {'source': 14, 'target': 24, 'value': 19.28686405533813}, {'source': 15, 'target': 0, 'value': 6.5242586658094766}, {'source': 15, 'target': 3, 'value': 9.977560056371123}, {'source': 15, 'target': 8, 'value': 3.1320413229400383}, {'source': 15, 'target': 15, 'value': 25.839929208749062}, {'source': 15, 'target': 27, 'value': 13.311287907598643}, {'source': 15, 'target': 29, 'value': 3.514275962164472}, {'source': 16, 'target': 7, 'value': 15.394413605162883}, {'source': 17, 'target': 14, 'value': 17.611132290380162}, {'source': 17, 'target': 24, 'value': 2.31792217189205}, {'source': 17, 'target': 27, 'value': 26.75822085295599}, {'source': 18, 'target': 10, 'value': 22.74628053580999}, {'source': 18, 'target': 17, 'value': 4.793156383287602}, {'source': 18, 'target': 21, 'value': 10.429610968861153}, {'source': 18, 'target': 27, 'value': 1.5061038578439638}, {'source': 19, 'target': 6, 'value': 10.898968848772531}, {'source': 19, 'target': 9, 'value': 11.5038682772521}, {'source': 19, 'target': 26, 'value': 3.154089934184855}, {'source': 20, 'target': 2, 'value': 24.15135615528216}, {'source': 20, 'target': 10, 'value': 18.544687131523148}, {'source': 21, 'target': 2, 'value': 12.005192222253655}, {'source': 21, 'target': 17, 'value': 29.118961895333918}, {'source': 22, 'target': 21, 'value': 9.960035145257821}, {'source': 23, 'target': 11, 'value': 18.04245497130028}, {'source': 23, 'target': 16, 'value': 12.418323500270823}, {'source': 24, 'target': 7, 'value': 8.572046967595897}, {'source': 25, 'target': 8, 'value': 12.564916644169609}, {'source': 28, 'target': 8, 'value': 20.42348316739961}, {'source': 28, 'target': 19, 'value': 11.364062023470328}, {'source': 28, 'target': 29, 'value': 29.890352737232742}, {'source': 29, 'target': 2, 'value': 15.190747528059111}, {'source': 29, 'target': 5, 'value': 6.435134302330926}, {'source': 29, 'target': 19, 'value': 1.6097541379683031}], 'nodes': [{'group': 22, 'name': 'i0'}, {'group': 8, 'name': 'i1'}, {'group': 23, 'name': 'i2'}, {'group': 80, 'name': 'i3'}, {'group': 28, 'name': 'i4'}, {'group': 95, 'name': 'i5'}, {'group': 32, 'name': 'i6'}, {'group': 2, 'name': 'i7'}, {'group': 21, 'name': 'i8'}, {'group': 96, 'name': 'i9'}, {'group': 12, 'name': 'i10'}, {'group': 44, 'name': 'i11'}, {'group': 69, 'name': 'i12'}, {'group': 58, 'name': 'i13'}, {'group': 53, 'name': 'i14'}, {'group': 59, 'name': 'i15'}, {'group': 6, 'name': 'i16'}, {'group': 38, 'name': 'i17'}, {'group': 17, 'name': 'i18'}, {'group': 11, 'name': 'i19'}, {'group': 17, 'name': 'i20'}, {'group': 39, 'name': 'i21'}, {'group': 74, 'name': 'i22'}, {'group': 3, 'name': 'i23'}, {'group': 46, 'name': 'i24'}, {'group': 43, 'name': 'i25'}, {'group': 24, 'name': 'i26'}, {'group': 85, 'name': 'i27'}, {'group': 98, 'name': 'i28'}, {'group': 49, 'name': 'i29'}]} ;
#
#   force
#       .nodes(graph.nodes)
#       .links(graph.links)
#       .start();
#
#   var link = svg.selectAll(".link")
#       .data(graph.links)
#       .enter().append("line")
#       .attr("class", "link")
#       .style("stroke-width", function(d) { return Math.sqrt(d.value); });
#
#   var node = svg.selectAll(".node")
#       .data(graph.nodes)
#     .enter().append("circle")
#       .attr("class", "node")
#       .attr("r", 8)
#       .style("fill", function(d) { return color(d.group); })
#       .on("dblclick",function(d){
#         console.log("Hello world");
#         d.fixed = ! d.fixed;
#
#         if(d.fixed){
#           d3.select(this).style("stroke", "black").style("stroke-width", "4px");
#         }else{
#           d3.select(this).style("stroke", "black").style("stroke-width", "0px");
#         }
#
#       })
#       .call(force.drag);
#
#   node.append("title")
#       .text(function(d) { return d.name; });
#
#   force.on("tick", function() {
#     link.attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; });
#
#     node.attr("cx", function(d) { return d.x; })
#         .attr("cy", function(d) { return d.y; });
#   });
#
# //});
#
#                 </script>
# =========================================================
