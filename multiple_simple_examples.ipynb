# %% [markdown]
# # Multiple Simple D3 Examples using d3_lib.py

# %% [markdown]
# This notebook demonstrates the use of single-line calls to D3 visualizations via the simple d3_lib.py file and referenced css and js files.

# %%
import d3_lib
import random

import sys
reload(sys)
sys.setdefaultencoding("utf-8")

# import IPython as IPython
# from IPython.core.display import HTML
# from __future__ import print_function

# from IPython.display import clear_output, display
# from ipywidgets import interact, interactive, fixed
# import ipywidgets as widgets

# display(HTML('<script src="http://cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min.js"></script>'))

# %%
# num_nodes = 30
# num_edges = 0.05

# slider_nodes = widgets.IntSlider()
# slider_edges = widgets.IntSlider()
# submit_button = widgets.Button(description="Create Graph")


# def slider_nodes_handler(change):
#     num_nodes = change['new']
    
# def slider_edges_handler(change):
#     num_edges = change['new']

    
# def on_button_click(change):
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#     display_graph(num_nodes, num_edges)
#     print("=========================================================")
    
# slider_nodes.observe(slider_nodes_handler, names='value')
# slider_edges.observe(slider_edges_handler, names='value')

# submit_button.on_click(on_button_click)


# def display_graph(num_nodes, num_edges): 
#     graph = {"nodes": [], "links": []}
#     for i in range(num_nodes):
#         graph["nodes"].append( {"name": "i" + str(i), "group": int(random.uniform(1,100))} )
#     for i in range(num_nodes):
#         for j in range(num_nodes):
#             if random.uniform(0,1) < num_edges:
#                 graph["links"].append( {"source": i, "target": j, "value": random.uniform(1,30)} )
#     clear_output()
#     display(HTML(d3_lib.set_styles(['force_directed_graph'])))
#     display(HTML(d3_lib.draw_graph('force_directed_graph',{'data': graph})))

# %%
# IPython.display.display(slider_nodes)
# display(slider_edges)
# display(submit_button)
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))

# %% [markdown]
# # This next part i will start to import graphml

# %%
# from pygraphml import Graph
# from pygraphml import GraphMLParser

# parser = GraphMLParser()
# g = parser.parse("./data_sets/G.graphml")

# g.show()

# %%
# import sys
# import argparse
# import networkx as nx
# import community
# from networkx.readwrite import json_graph
# import json

# def graphmltojson(graphfile, outfile):
# 	"""
# 	Converts GraphML file to json while adding communities/modularity groups
# 	using python-louvain. JSON output is usable with D3 force layout.
# 	Usage:
# 	>>> python convert.py -i mygraph.graphml -o outfile.json
# 	"""
	
# 	G = nx.read_graphml(graphfile)	

# 	#finds best community using louvain
# 	partition = community.best_partition(G)

# 	#adds partition/community number as attribute named 'modularitygroup'
# 	for n,d in G.nodes_iter(data=True):
# 		d['modularitygroup'] = partition[n]

# 	node_link = json_graph.node_link_data(G)
# 	json = json_graph.dumps(node_link)
	
# 	# Write to file
# 	fo = open(outfile, "w")
# 	fo.write(json);
# 	fo.close()
