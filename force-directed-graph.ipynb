# %% [markdown]
# The code below will load d3.js with require.js
#
# If you don't know what require js does, all you need to know is it manages dependencies, and we need to hook into it in order for our page to correctly access the d3 module

# %%
# %%javascript
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min"
#   }
# });
#
# require(["d3"], function(d3) {
# //   d3.select("body").prepend("h1").text("Successfully loaded D3 version " + d3.version);
#     alert("Loaded d3");
#     console.log("%c%s",
#             "color: red; background: yellow; font-size: 24px;",
#             "Successfully loaded d3:");
#     console.log(d3);
# });

# %%
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets
import d3_lib
import json
import random
# HTML('<script src="lib/d3/d3.min.js"></script>')

# num_nodes = 30
# num_edges = 0.05

# slider_nodes = widgets.IntSlider()
# slider_edges = widgets.IntSlider()
submit_button = widgets.Button(description="Create Graph")

# display(slider_nodes)
# display(slider_edges)
display(submit_button)


def slider_nodes_handler(change):
    num_nodes = change['new']
    
def slider_edges_handler(change):
    num_edges = change['new']

    
def on_button_click(change):
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    display_graph()
#     print("=========================================================")
    
# slider_nodes.observe(slider_nodes_handler, names='value')
# slider_edges.observe(slider_edges_handler, names='value')

submit_button.on_click(on_button_click)



def display_graph(): 
    clear_output()
#     display(HTML(d3_lib.set_styles(['force_directed_graph'])))
#     display(HTML(d3_lib.draw_graph_from_graphml('force_directed_graph', "./data_sets/G.graphml")))
    display(HTML(d3_lib.set_styles(['custom_force_directed'])))
    display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('custom_force_directed', "./data_sets/G.graphml", "communicability", .000001)))

#     display(HTML(d3_lib.draw_graph_from_graphml('custom_force_directed', "./data_sets/G.graphml")))
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
# @-webkit-keyframes dash {
#   to {
#     stroke-dashoffset: 1000;
#   }
# }
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
#   -webkit-animation: dash 60s linear infinite;
#   animation-direction: reverse;
#   stroke-dasharray: 8;
# }
#
# .fixed {
#   border: 2px solid black;
# }
# </style>
#                 <div id='maindiv9868861955'></div>
#
#                 <script>
#                     var width = 1000;
# var height = 1000;
# var default_color = "grey"
# var color = d3.scale.category20();
#
# var graph = {"graph": {"node_default": {}, "edge_default": {}}, "nodes": [{"x": 232, "id": "2", "y": 7}, {"x": 301, "id": "17", "y": 384}, {"x": 175, "id": "11", "y": 418}, {"x": 295, "id": "29", "y": 57}, {"x": 121, "id": "37", "y": 170}, {"x": 86, "id": "20", "y": 311}, {"x": 174, "id": "15", "y": 155}, {"x": 444, "id": "38", "y": 140}, {"x": 127, "id": "10", "y": 490}, {"x": 418, "id": "9", "y": 421}, {"x": 479, "id": "50", "y": 220}, {"x": 61, "id": "31", "y": 262}, {"x": 207, "id": "45", "y": 219}, {"x": 124, "id": "25", "y": 400}, {"x": 245, "id": "7", "y": 345}, {"x": 13, "id": "24", "y": 240}, {"x": 496, "id": "33", "y": 166}, {"x": 15, "id": "1", "y": 276}, {"x": 289, "id": "40", "y": 420}, {"x": 46, "id": "8", "y": 332}, {"x": 56, "id": "49", "y": 472}, {"x": 276, "id": "36", "y": 184}, {"x": 387, "id": "14", "y": 490}, {"x": 412, "id": "42", "y": 331}, {"x": 345, "