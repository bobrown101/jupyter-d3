# %% [markdown]
# The code below will load d3.js with require.js
#
# If you don't know what require js does, all you need to know is it manages dependencies, and we need to hook into it in order for our page to correctly access the d3 module

# %%
# %%javascript
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min"
#   }
# });
#
# require(["d3"], function(d3) {
# //   d3.select("body").prepend("h1").text("Successfully loaded D3 version " + d3.version);
#     alert("Loaded d3");
#     console.log("%c%s",
#             "color: red; background: yellow; font-size: 24px;",
#             "Successfully loaded d3:");
#     console.log(d3);
# });

# %%
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets
import d3_lib
import json
import random
# HTML('<script src="lib/d3/d3.min.js"></script>')

# num_nodes = 30
# num_edges = 0.05

# slider_nodes = widgets.IntSlider()
# slider_edges = widgets.IntSlider()
submit_button = widgets.Button(description="Create Graph")

# display(slider_nodes)
# display(slider_edges)
display(submit_button)


def slider_nodes_handler(change):
    num_nodes = change['new']
    
def slider_edges_handler(change):
    num_edges = change['new']

    
def on_button_click(change):
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    display_graph()
#     print("=========================================================")
    
# slider_nodes.observe(slider_nodes_handler, names='value')
# slider_edges.observe(slider_edges_handler, names='value')

submit_button.on_click(on_button_click)



def display_graph(): 
    clear_output()
    display(HTML(d3_lib.set_styles(['arc'])))
#     display(HTML(d3_lib.draw_graph_from_graphml('arc', "./data_sets/G.graphml")))
    display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "degree_centrality", 30)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "load_centrality", 10000)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "closeness_centrality", 10)))
#     display(HTML(d3_lib.draw_graph_from_graphml_with_algorithm('arc', "./data_sets/G.graphml", "communicability", 100)))
# Out:
# <style>@-webkit-keyframes dash {
#   to {
#     stroke-dashoffset: 1000;
#   }
# }
#
# body {
#     font-family: 'Source Sans Pro', sans-serif;
#     font-weight: 300;
# }
#
# b {
#     font-weight: 900;
# }
#
# .outline {
#     fill: none;
#     stroke: #888888;
#     stroke-width: 1px;
# }
#
# #tooltip {
#     font-size: 10pt;
#     font-weight: 900;
#
#     fill: #000000;
#     stroke: #ffffff;
#     stroke-width: 0.25px;
# }
#
# .node {
#     stroke: #ffffff;
#     stroke-weight: 1px;
# }
#
# .link {
#     fill: none;
#     stroke: #888888;
#     stroke-weight: 1px;
#     stroke-opacity: 0.5;
#     /*-webkit-animation: dash;*/
#
#
# }
#
# /*.animated-link {
#   animation: dash 60s linear infinite;
#   animation-direction: reverse;
#     stroke-dasharray: 8;
# }*/
#
# .highlight {
#     stroke: red;
#     stroke-weight: 4px;
#     stroke-opacity: 1.0;
# }
# </style>
# Un-normalized centrality numbers
# {   '1': 0.24489795918367346,
#     '10': 0.2857142857142857,
#     '11': 0.36734693877551017,
#     '12': 0.4897959183673469,
#     '13': 0.4081632653061224,
#     '14': 0.2040816326530612,
#     '15': 0.3877551020408163,
#     '16': 0.42857142857142855,
#     '17': 0.4693877551020408,
#     '18': 0.32653061224489793,
#     '19': 0.5102040816326531,
#     '2': 0.16326530612244897,
#     '20': 0.3877551020408163,
#     '21': 0.3469387755102041,
#     '22': 0.44897959183673464,
#     '23': 0.42857142857142855,
#     '24': 0.24489795918367346,
#     '25': 0.4081632653061224,
#     '26': 0.2040816326530612,
#     '27': 0.2857142857142857,
#     '28': 0.3469387755102041,
#     '29': 0.3061224489795918,
#     '3': 0.44897959183673464,
#     '30': 0.4081632653061224,
#     '31': 0.2857142857142857,
#     '32': 0.5714285714285714,
#     '33': 0.2857142857142857,
#     '34': 0.3877551020408163,
#     '35': 0.08163265306122448,
#     '36': 0.4081632653061224,
#     '37': 0.2857142857142857,
#     '38': 0.3469387755102041,
#     '39': 0.32653061224489793,
#     '4': 0.42857142857142855,
#     '40': 0.42857142857142855,
#     '41': 0.32653061224489793,
#     '42': 0.4081632653061224,
#     '43': 0.5510204081632653,
#     '44': 0.3061224489795918,
#     '45': 0.4897959183673469,
#     '46': 0.2040816326530612,
#     '47': 0.24489795918367346,
#     '48': 0.5306122448979591,
#     '49': 0.24489795918367346,
#     '5': 0.3877551020408163,
#     '50': 0.3469387755102041,
#     '6': 0.36734693877551017,
#     '7': 0.5306122448979591,
#     '8': 0.36734693877551017,
#     '9': 0.26530612244897955}
# {   '1': 0.4090909090909091,
#     '10': 0.4772727272727273,
#     '11': 0.6136363636363636,
#     '12': 0.8181818181818182,
#     '13': 0.6818181818181818,
#     '14': 0.3409090909090909,
#     '15': 0.6477272727272728,
#     '16': 0.7159090909090909,
#     '17': 0.7840909090909092,
#     '18': 0.5454545454545455,
#     '19': 0.8522727272727274,
#     '2': 0.27272727272727276,
#     '20': 0.6477272727272728,
#     '21': 0.5795454545454546,
#     '22': 0.75,
#     '23': 0.7159090909090909,
#     '24': 0.4090909090909091,
#     '25': 0.6818181818181818,
#     '26': 0.3409090909090909,
#     '27': 0.4772727272727273,
#     '28': 0.5795454545454546,
#     '29': 0.5113636363636364,
#     '3': 0.75,
#     '30': 0.6818181818181818,
#     '31': 0.4772727272727273,
#     '32': 0.9545454545454546,
#     '33': 0.4772727272727273,
#     '34': 0.6477272727272728,
#     '35': 0.13636363636363638,
#     '36': 0.6818181818181818,
#     '37': 0.4772727272727273,
#     '38': 0.5795454545454546,
#     '39': 0.5454545454545455,
#     '4': 0.7159090909090909,
#     '40': 0.7159090909090909,
#     '41': 0.5454545454545455,
#     '42': 0.6818181818181818,
#     '43': 0.9204545454545454,
#     '44': 0.5113636363636364,
#     '45': 0.8181818181818182,
#     '46': 0.3409090909090909,
#     '47': 0.4090909090909091,
#     '48': 0.8863636363636364,
#     '49': 0.4090909090909091,
#     '5': 0.6477272727272728,
#     '50': 0.5795454545454546,
#     '6': 0.6136363636363636,
#     '7': 0.8863636363636364,
#     '8': 0.6136363636363636,
#     '9': 0.4431818181818182}
#                 <div id='maindiv1759616379'></div>
#
#                 <script>
#                     /* GLOBALS */
#
# var width  = 1000;           // width of svg image
# var height = 1000;           // height of svg image
# var margin = 20;            // amount of margin around plot area
# var pad = margin / 2;       // actual padding amount
# var radius = 10;             // fixed node radius
# var yfixed = 400 - pad - radius;  // y position for all nodes
# var xfixed = pad + radius;
#
# var json_data = {"graph": {"node_default": {}, "edge_default": {}}, "directed": false, "nodes": [{"y": 253, "id": "19", "algorithm_filter": 0.8522727272727274, "x": 200}, {"y": 377, "id": "18", "algorithm_filter": 0.5454545454545455, "x": 425}, {"y": 311, "id": "20", "algorithm_filter": 0.6477272727272728, "x": 86}, {"y": 170, "id": "37", "algorithm_filter": 0.4772727272727273, "x": 121}, {"y": 10, "id": "35", "algorithm_filter": 0.13636363636363638, "x": 72}, {"y": 472, "id": "49", "algorithm_filter": 0.4090909090909091, "x": 56}, {"y": 155, "id": "15", "algorithm_filter": 0.6477272727272728, "x": 174}, {"y": 413, "id": "6", "algorithm_filter": 0.6136363636363636, "x": 359}, {"y": 376, "id": "23", "algorithm_filter": 0.7159090909090909, "x": 156}, {"y": 7, "id": "2", "algorithm_filter": 0.27272727272727276, "x": 232}, {"y": 113, "id": "27", "algorithm_filter": 0.4772727272727273, "x": 471}, {"y": 219, "id": "12", "algorithm_filter": 0.8181818181818182, "x": 386}, {"y": 412, "id": "46", "algorithm_filter": 0.3409090909090909, "x": 477}, {"y": 345, "id": "7", "algorithm_filter": 0.8863636363636364, "x": 245}, {"y": 166, "id": "33", "algorithm_filter": 0.4772727272727273, "x": 496}, {"y": 429, "id": "30", "algorithm_filter": 0.6818181818181818, "x": 215}, {"y": 332, "id": "8", "algorithm_filter": 0.6136363636363636, "x": 46}, {"y": 331, "id": "34", "algorithm_filter": 0.6477272727272728, "x": 87}, {"y": 163, "id": "21", "algorithm_filter": 0.5795454545454546, "x": 463}, {"y": 224, "id": "48", "algorithm_filter": 0.8863636363636364, "x": 315}, {"y": 493, "id": "44", "algorithm_filter": 0.5113636363636364, "x": 252}, {"y": 149, "id": "4", "algorithm_filter": 0.7159090909090909, "x": 328}, {"y": 249, "id": "43", "algorithm_filter": 0.9204545454545454, "x": 345}, {"y": 384, "id": "17", "algorithm_filter": 0.7840909090909092, "x": 301}, {"y": 471, "id": "47", "algorithm_filter": 0.4090909090909091, "x": 20}, {"y": 57, "id": "29", "algorithm_filter": 0.5113636363636364, "x": 295}, {"y": 331, "id": "42", "algorithm_filter": 0.6818181818181818, "x": 412}, {"y": 421, "id": "9", "algorithm_filter": 0.4431818181818182, "x": 418}, {"y": 140, "id": "38", "algorithm_filter": 0.5795454545454546, "x": 444}, {"y": 265, "id": "32", "algorithm_filter": 0.9545454545454546, "x": 309}, {"y": 291, "id": "16", "algorithm_filter": 0.7159090909090909, "x": 444}, {"y": 219, "id": "45", "algorithm_filter": 0.8181818181818182, "x": 207}, {"y": 240, "id": "24", "algorithm_filter": 0.4090909090909091, "x": 13}, {"y": 490, "id": "10", "algorithm_filter": 0.4772727272727273, "x": 127}, {"y": 184, "id": "36", "algorithm_filter": 0.6818181818181818, "x": 276}, {"y": 262, "id": "31", "algorithm_filter": 0.4772727272727273, "x": 61}, {"y": 403, "id": "39", "algorithm_filter": 0.5454545454545455, "x": 394}, {"y": 105, "id": "5", "algorithm_filter": 0.6477272727272728, "x": 339}, {"y": 34, "id": "26", "algorithm_filter": 0.3409090909090909, "x": 219}, {"y": 490, "id": "14", "algorithm_filter": 0.3409090909090909, "x": 387}, {"y": 368, "id": "22", "algorithm_filter": 0.75, "x": 148}, {"y": 129, "id": "41", "algorithm_filter": 0.5454545454545455, "x": 423}, {"y": 276, "id": "1", "algorithm_filter": 0.4090909090909091, "x": 15}, {"y": 401, "id": "13", "algorithm_filter": 0.6818181818181818, "x": 184}, {"y": 420, "id": "40", "algorithm_filter": 0.7159090909090909, "x": 289}, {"y": 204, "id": "28", "algorithm_filter": 0.5795454545454546, "x": 460}, {"y": 418, "id": "11", "algorithm_filter": 0.6136363636363636, "x": 175}, {"y": 400, "id": "25", "algorithm_filter": 0.6818181818181818, "x": 124}, {"y": 220, "id": "50", "algorithm_filter": 0.5795454545454546, "x": 479}, {"y": 184, "id": "3", "algorithm_filter": 0.75, "x": 333}], "multigraph": false, "links": [{"source": 0, "target": 2}, {"source": 0, "target": 3}, {"source": 0, "target": 32}, {"source": 0, "target": 8}, {"source": 0, "target": 34}, {"source": 0, "target": 11}, {"source": 0, "target": 13}, {"source": 0, "targe ...
